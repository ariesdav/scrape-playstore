# %%
pip install google-play-scraper

# %%
from google_play_scraper import app

result = app(
    'mam.reader.ipusnas',
    lang='en',
    country='us'
)

print(f"App: {result['title']}")
print(f"Rating: {result['score']}")
print(f"Downloads: {result['installs']}")
print(f"Price: {result['free']}")
# Out:
# App: iPusnas
# Rating: 3.5714285
# Downloads: 1,000,000+
# Price: True

# %%
from google_play_scraper import reviews, Sort

result, continuation_token = reviews(
    'mam.reader.ipusnas',
    lang='en',
    country='us',
    sort=Sort.NEWEST,
    count=4000
)
for review in result:
  print(f"{review['userName']}: {review['score']} stars")
  print(f"Review: {review['content']}")
  print(f"Date: {review['at']}")
# Out:
# A Google user: 4 stars
# Review: novel lockwood and co nya lengkapin plissss
# Date: 2026-06-26 01:19:13
# A Google user: 1 stars
# Review: tidak bisa membuka buku yang sudah dipinjam, tertulis bisa di baca, tapi ketika di klik tidak bisa memuat ke halaman buku, padahal saya sudah menggunakan aplikasi resmi, dan tidak ada modifikasi apapun, tolong diperbaiki maslaah ini, apakah ini bug, gangguan atau semacamnya yang jelas tolong diperbaiki.
# Date: 2026-06-25 08:05:43
# A Google user: 1 stars
# Review: Kenapa saya tidak bisa membaca buku yang sudah saya pinjam tiba-tiba setelah melakukan login di laptop? Saya tidak bisa membaca buku di laptop dan ketika akan membaca di perangkat hp ada pop up kalau tidak bisa memuat karena tidak dapat memverifikasi perangkat. Mohon jawabannya... padahal kmrn sore masih bisa, ini tiba-tiba trouble. Terus setelah lihat review lain juga banyak masalah serupa. Tolong ini bagaimana?
# Date: 2026-06-25 07:43:20
# A Google user: 2 stars
# ...

# %%
import pandas as pd
df=pd.DataFrame(result)
df.to_csv('ipusnasdata_raw.csv', index=False)

# %%
df
# Out:
#                                   reviewId       userName  \
# 0     5c4937e1-8a6f-46f3-85b5-d8d51a4871eb  A Google user
# 1     2664d873-11c9-4543-9218-82610b6e333e  A Google user
# 2     b0dcd850-ef00-43da-b52a-ebcfea80e4dc  A Google user
# 3     4eddc1c4-b7fb-463f-8fea-e29e3338219d  A Google user
# 4     a0d91fe5-75ed-4b11-a2f8-0ab33d5f8639  A Google user
# ...                                    ...            ...
# 3995  f244f517-719e-40ef-8614-0d166c762c59  A Google user
# 3996  08c2da7e-065f-4ce8-8d28-c4c5cf5d9dcb  A Google user
# 3997  10623d71-fd0f-4768-b63b-dd69889553fe  A Google user
# 3998  68d9f22c-293c-4fa2-b4e8-cf48287ac1d5  A Google user
# 3999  6397fdde-4f06-41b6-bde2-223bf3006142  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# ...

# %%
df['at'] = pd.to_datetime(df['at'])
start = pd.to_datetime("2021-01-01")
end   = pd.to_datetime("2026-05-16")
mask = (df['at'] >= start) & (df['at'] <= end)
filtered = df[mask]

filtered[['userName','score','content','at']]
# Out:
#            userName  score                                            content  \
# 91    A Google user      2  sebagai warga yang dengan dana minim, tapi ing...
# 92    A Google user      1  hp saya android 9 mendadak sudah tidak bisa di...
# 93    A Google user      2  update terbaru 9 mei 2026 alangkah susahnya ya...
# 94    A Google user      5                                   Cant even log in
# 95    A Google user      1  aplikasinya makin lama makin jelek aja. dari y...
# ...             ...    ...                                                ...
# 3600  A Google user      2  Saya kira filter pencariannya kurang variatif,...
# 3601  A Google user      5                               Lagi maintenance ya?
# 3602  A Google user      2                        i can't open this app.. -,-
# 3603  A Google user      3  Saya cukup puas dengan aplikasi perpustakaan i...
# 3604  A Google user      3  Tidak bisa menggunakan fungsi search. Mohon di...
#
#                       at
# ...

# %%
filtered.to_csv("ipusnasdata.csv", index=False)

# %%
from google.colab import files
files.download('ipusnasdata.csv')
